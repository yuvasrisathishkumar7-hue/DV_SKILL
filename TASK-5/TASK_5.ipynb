# %%
import pandas as pd

# %% [markdown]
# **1. LOAD DATASET**

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/healthcare_dataset.csv")

print("First 5 Records:")
print(df.head())

print("\nDataset Shape:")
print(df.shape)

print("\nColumn Information:")
print(df.info())

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# First 5 Records:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %% [markdown]
# **2. CLEAN MISSING MEDICAL CODES**

# %%
df["Medical Condition"] = df["Medical Condition"].fillna("Unknown")

# %% [markdown]
# **3. STANDARDIZE DATE ATTRIBUTES**

# %%
df["Date of Admission"] = pd.to_datetime(
    df["Date of Admission"]
)

df["Discharge Date"] = pd.to_datetime(
    df["Discharge Date"]
)

# %% [markdown]
# **4. CATEGORIZE ADMISSIONS BY URGENCY**

# %%
df["Urgency"] = df["Admission Type"].apply(
    lambda x: x if x in ["Emergency", "Elective", "Urgent"]
    else "Unknown"
)

print("\nAdmission by Urgency:")
print(df["Urgency"].value_counts())
# Out:
# Admission by Urgency:
# Urgency
# Elective     18655
# Urgent       18576
# Emergency    18269
# Name: count, dtype: int64

# %% [markdown]
# **5. CALCULATE HOSPITAL STAY**

# %%
df["Hospital Stay Days"] = (
    df["Discharge Date"] - df["Date of Admission"]
).dt.days

# %% [markdown]
# **6. BILLING AMOUNT ANALYSI**

# %%
print("\nBilling Amount Statistics:")
print(df["Billing Amount"].describe())
# Out:
# Billing Amount Statistics:
# count    55500.000000
# mean     25539.316097
# std      14211.454431
# min      -2008.492140
# 25%      13241.224652
# 50%      25538.069376
# 75%      37820.508436
# max      52764.276736
# Name: Billing Amount, dtype: float64

# %% [markdown]
# **7. HOSPITAL STAY ANALYSIS**

# %%
print("\nHospital Stay Statistics:")
print(df["Hospital Stay Days"].describe())
# Out:
# Hospital Stay Statistics:
# count    55500.000000
# mean        15.509009
# std          8.659600
# min          1.000000
# 25%          8.000000
# 50%         15.000000
# 75%         23.000000
# max         30.000000
# Name: Hospital Stay Days, dtype: float64

# %% [markdown]
# **8. DEMOGRAPHIC SEGMENTATION**

# %%
print("\nDemographics by Medical Condition:")

demographics = df.groupby("Medical Condition")["Age"].agg(
    ["count", "mean", "min", "max"]
)

print(demographics)
# Out:
# Demographics by Medical Condition:
#                    count       mean  min  max
# Medical Condition
# Arthritis           9308  51.565320   13   89
# Asthma              9185  51.575830   13   89
# Cancer              9227  51.558795   13   89
# Diabetes            9304  51.554170   14   89
# Hypertension        9245  51.741915   13   89
# Obesity             9231  51.240277   13   89

# %% [markdown]
# **9. FINAL CLEANED DATA**

# %%
print("\nFinal Dataset:")
print(df.head())

print("\nFinal Shape:")
print(df.shape)
# Out:
# Final Dataset:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...
